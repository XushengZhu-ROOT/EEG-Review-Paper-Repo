# %%
import mne

# %%
raw = mne.io.read_raw_edf('/home/dung/Documents/EEG-Review-Paper-Repo/data/ISRUC_S3/RawData/1/1.edf', preload=True)
print(raw.info)
# Out:
# Extracting EDF parameters from /home/dung/Documents/EEG-Review-Paper-Repo/data/ISRUC_S3/RawData/1/1.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5723999  =      0.000 ... 28619.995 secs...
# <Info | 8 non-empty values
#  bads: []
#  ch_names: LOC-A2, ROC-A1, F3-A2, C3-A2, O1-A2, F4-A1, C4-A1, O2-A1, X1, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 100.0 Hz
#  meas_date: 2009-03-28 23:19:00 UTC
#  nchan: 19
#  projs: []
#  sfreq: 200.0 Hz
#  subject_info: <subject_info | his_id: 1>
# >
